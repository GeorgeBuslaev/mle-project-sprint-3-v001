# %%
import requests
import pandas as pd
import json

# Функция для отправки post-запроса.
# Выбирает n случайных строк из файла weather.csv.gz, упаковывает в json и отправляет
# На указанный адрес
def main(ip = "127.0.0.1", port = 4601, i = 10, t = 30):
    dataset = pd.read_csv("services/app/data/initial_data.csv", index_col = 0).dropna().sample(n=i, random_state=23)
    dataset = dataset.astype({'floor' : 'str',
                                        'kitchen_area' : 'str',
                                        'living_area' : 'str',
                                        'rooms' : 'str',
                                        'is_apartment' : 'str',
                                        'studio' : 'str',
                                        'total_area' : 'str',
                                        'build_year' : 'str',
                                        'building_type_int' : 'str',
                                        'flats_count' : 'str',
                                        'ceiling_height' : 'str',
                                        'longitude' : 'str',
                                        'latitude' : 'str',
                                        'floors_total' : 'str',
                                        'has_elevator' : 'str',
                                        'price' : 'str'
                                        })
    dataset.drop(["price"], axis=1, inplace=True)

    for id in dataset.index:
        data = dict(dataset.loc[id, :])
        data = json.dumps(data)
        response = requests.post(
            f"http://{ip}:{port}/api/real_estate/{id}",
            data=data,
        )
        print(f"Status code:\n{response.status_code}")
        print(f"Result:\n{response.json()}")

if __name__ == "__main__":
    main()
# Out:
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '30407', 'price': 10764181.569678595}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '132150', 'price': 7447983.874799783}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '54100', 'price': 12199759.961293697}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '100060', 'price': 11493764.578591892}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '49453', 'price': 16499660.106059896}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '20861', 'price': 14373270.579906272}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '7843', 'price': 10367745.528504327}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '17738', 'price': 10881230.820549872}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '79549', 'price': 17072289.489902887}}
# Status code:
# 200
# Result:
# {'predicted_value': {'user_id': '14578', 'price': 20085896.48757454}}
